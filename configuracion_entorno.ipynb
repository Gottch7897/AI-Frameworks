# %% [markdown]
# # Configuracion de dependencias y entorno
#
# Este notebook prepara el entorno para ejecutar el flujo de PyTorch del proyecto:
# descarga de imagenes, limpieza y modelos en PyTorch.
#
# Ejecuta primero la celda de instalacion y despues reinicia el kernel antes de continuar.

# %%
# Instala dependencias base para el flujo de PyTorch
# Ejecuta esta celda en el kernel del notebook
# %pip install --upgrade pip
# %pip install --upgrade pillow tqdm imagededup icrawler scikit-learn matplotlib seaborn torch torchvision tensorboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path

import matplotlib
import sklearn
import torch
from icrawler.builtin import BingImageCrawler, GoogleImageCrawler
from imagededup.methods import PHash
from PIL import Image, ImageOps

PROJECT_ROOT = Path('.').resolve()
DATA_ROOT = PROJECT_ROOT / 'data'
ARTIFACTS_ROOT = PROJECT_ROOT / 'artifacts'
for folder in (DATA_ROOT, ARTIFACTS_ROOT):
    folder.mkdir(parents=True, exist_ok=True)

print('Proyecto:', PROJECT_ROOT)
print('Data root:', DATA_ROOT)
print('Artifacts root:', ARTIFACTS_ROOT)
print('Torch:', torch.__version__)
print('Scikit-learn:', sklearn.__version__)
print('Matplotlib:', matplotlib.__version__)
print('GPU disponible en PyTorch:', torch.cuda.is_available())
# Out:
# Proyecto: /home/martin/Documents/GitHub/AI-Frameworks
# Data root: /home/martin/Documents/GitHub/AI-Frameworks/data
# Artifacts root: /home/martin/Documents/GitHub/AI-Frameworks/artifacts
# Torch: 2.12.1+cpu
# Scikit-learn: 1.7.2
# Matplotlib: 3.10.9
# GPU disponible en PyTorch: False

# %%
# Ajustes utiles para el flujo de PyTorch

# Semilla basica para reproducibilidad
SEED = 42
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
print('Semilla aplicada:', SEED)
# Out:
# Semilla aplicada: 42

# %% [markdown]
# ## Siguiente paso
#
# Una vez ejecutado este notebook, ya puedes abrir `imagenes.ipynb` y `pytorch_workflow.py`
# con el entorno preparado.
